# %% [markdown]
# # Experiments
#
# Espacio de trabajo para probar nuevas hipótesis y estrategias antes de moverlas a `research/`.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np

# Tu código experimental aquí
